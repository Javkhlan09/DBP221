# %%
# Энэ нь хэдэн ширхэг item листэд байгааг харуулдаг.
mylist = ["apple", "banana", "cherry"]
x = len(mylist)
x
# Out:
# 3

# %%
# Томоор бичигдсэн үсгүүдийг жижиг хэлбэрт оруулдаг.
message = 'PYTHON IS FUN'


print(message.lower())

# Output: python is fun
# Out:
# python is fun

# %%
#use a dictionary with ascii codes to replace 83 (S) with 80 (P):
mydict = {83:  80}
txt = "Hello Sam!"
print(txt.translate(mydict))
# Out:
# Hello Pam!

# %%
#Энэ нь техт жижиг үсгээр бичигдсэн эсэхийг шалгадаг
txt = "hello world!"

x = txt.islower()

print(x)
# Out:
# True

# %%
# Утгуудын хооронд зай үлдээдэг бололтой
txt = "banana"

x = txt.ljust(10)

print(x, "is my favorite fruit.")
# Out:
# banana     is my favorite fruit.

# %%
# Үсгүүдийг бүгдийн том болгодог
message = 'python is fun'

print(message.upper())

# Output: PYTHON IS FU
# Out:
# PYTHON IS FUN

# %%
# Тухайн утга бүхий техт нь тодорхой бүхий үгээр эхэлж байгаа эсэхийг шалгадаг
message = 'Python is fun'

print(message.startswith('Python'))

# Output: True
# Out:
# True

# %%
#Техтийн бүх үсэг том эсэхийг шалгадаг
txt = "THIS IS NOW!"

x = txt.isupper()

print(x)
# Out:
# True

# %%
# баруун талаас нь зайтай бичигддэг бололтой
txt = "banana"

x = txt.rjust(20)

print(x, "is my favorite fruit.")
# Out:
#               banana is my favorite fruit.

# %%
# Тухайн тодотгосон хэсэг нь хэддүгээр тооллын дараалалаас эхэлж байгааг хэлж өгдөг
txt = "Hello, welcome to my world."

x = txt.find("welcome")

print(x)
# Out:
# 7

# %%
# Тодорхой утгаар төгсөж байгаа нь үнэн эсэхийг асуудаг
message = 'Python is fun'

# check if the message ends with fun
print(message.endswith('fun'))

# Output: True
# Out:
# True

# %%
# Тухайн хэсэг нь зөвхөн тооноос бүрдсэн эсэхийг шалгадаг
txt = "56553"

x = txt.isnumeric()

print(x)
# Out:
# True

# %%
# Утгыг голд нь бичдэг юм шиг байна
txt = "banana"

x = txt.center(20)

print(x)
# Out:
#        banana

# %%
# баруун нь эхэлж уг утга хаана байгааг нь тоолдог бололтой
txt = "Mi casa, su casa."

x = txt.rfind("casa")

print(x)
# Out:
# 12

# %%
# 
txt = "Hello, welcome to my world."

x = txt.rfind("e")

print(x)
# Out:
# 13

# %%
txt = "Hello, welcome to my world."

x = txt.rfind("e", 5, 10)

print(x)
# Out:
# 8

# %%
# dict ээс доторхой утгын орчуулсан утгыг гаргадаг
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = car.get("model")

print(x)
# Out:
# Mustang

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = car.get("price", 15000)

print(x)
# Out:
# 15000

# %%
#тухайн утга нь тоо болон үсэг агуулж байгаа нь үнэн эсэхийг шалгадаг
name = "M234onica"
print(name.isalnum())

# contains whitespace
name = "M3onica Gell22er "
print(name.isalnum())

name = "Mo3nicaGell22er"
print(name.isalnum())

name = "133"
print(name.isalnum())
# Out:
# True
# False
# True
# True

# %%
# Тухайн утга нь зөвхөн тоо агуулж байгаа нь үнэн эсэхийг шалгадаг
s = "28212"
print(s.isdecimal())

# contains alphabets
s = "32ladk3"
print(s.isdecimal())

# contains alphabets and spaces
s = "Mo3 nicaG el l22er"
print(s.isdecimal())
# Out:
# True
# False
# False

# %%
# 10 хүртэлх хэмжээнд өгөгдөл нэмж байх шиг байна
a = "hello"
b = "welcome to the jungle"
c = "10.000"

print(a.zfill(10))
print(b.zfill(10))
print(c.zfill(10))
# Out:
# 00000hello
# welcome to the jungle
# 000010.000

# %%
# Хүссэн техтээ хаана байгааг хайх
fruits = ['apple', 'banana', 'cherry']

x = fruits.index("cherry")

x
# Out:
# 2

# %%
#Тухайн утга нь зөвхөн үсэгээс бүрдсэн эсэхийг шалгадаг
txt = "CompanyX"

x = txt.isalpha()

print(x)
# Out:
# True

# %%
# Утгыг салгаж бичдэг
txt = "welcome to the jungle"

x = txt.split()

print(x)
# Out:
# ['welcome', 'to', 'the', 'jungle']

# %%
# Утга нэмж хүссэн хэсэгтэй оруулдаг бололтой
txt = "     banana     "

x = txt.strip()

print("of all fruits", x, "is my favorite")
# Out:
# of all fruits banana is my favorite

# %%
# өгөгдөлт буй илүүц зааж өгсөн утгуудыг цэвэрлэдэг
txt = ",,,,,rrttgg.....banana....rrr"

x = txt.strip(",.grt")

print(x)
# Out:
# banana

# %%
# хаана олдслныг зааж өгдөг бололтой
txt = "Mi casa, su casa."

x = txt.rindex("casa")

print(x)
# Out:
# 12

# %%
txt = "Hello, welcome to my world."

x = txt.rindex("e")

print(x)
# Out:
# 13

# %%
# Утга нь зөвхөн тооноос бүрдсэн эсэхийг шалгадаг
txt = "50800"

x = txt.isdigit()

print(x)
# Out:
# True

# %%
# утгуудыг салгадаг
txt = "apple, banana, cherry"

x = txt.rsplit(", ")

print(x)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# өгөгдөлт буй илүүц зааж өгсөн утгуудыг цэвэрлэдэг
txt = "banana,,,,,ssqqqww....."

x = txt.rstrip(",.qsw")

print(x)
# Out:
# banana

# %%
# Эхний үсгийг томоор бичдэг
txt = "hello, and welcome to my world."

x = txt.capitalize()

print (x)
# Out:
# Hello, and welcome to my world.

# %%
# Энэ нь зай байгаа эсэхийг шалгадаг
txt = "   "

x = txt.isspace()

print(x)
# Out:
# True

# %%
# Тодорхой утгыг салган тусгааралдаг бололтой
txt = "I could eat bananas all day"

x = txt.partition("bananas")

print(x)
# Out:
# ('I could eat ', 'bananas', ' all day')

# %%
# энийг сайн ойлгож чадсангүй ээ багшаа
txt = "I could eat bananas all day"

x = txt.partition("apples")

print(x)
# Out:
# ('I could eat bananas all day', '', '')

# %%
# дунд нь зайтай цуг оруулдаг бололтой
txt = "     banana     "

x = txt.lstrip()

print("of all fruits", x, "is my favorite")
# Out:
# of all fruits banana      is my favorite

# %%
#Өгөгдсөн илүү утгуудыг цэвэглэж байна

txt = ",,,,,ssaaww.....banana"

x = txt.lstrip(",.asw")

print(x)
# Out:
# banana

# %%
# том үсгүүдийг жижиг жижиг үсгүүдийг том болгож байна
txt = "Hello My Name Is PETER"

x = txt.swapcase()

print(x)
# Out:
# hELLO mY nAME iS peter

# %%
# бүх үгс томоор эхэлж байгаа эсэхийг шалгадаг
txt = "Hello, And Welcome To My World!"

x = txt.istitle()

print(x)
# Out:
# True

# %%
# энийг сайн ойлгож чадсангүй ээ багшаа
txt = "I could eat bananas all day, bananas are my favorite fruit"

x = txt.rpartition("bananas")

print(x)
# Out:
# ('I could eat bananas all day, ', 'bananas', ' are my favorite fruit')
