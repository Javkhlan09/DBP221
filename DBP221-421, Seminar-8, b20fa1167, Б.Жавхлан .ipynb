# %%
import pandas as pd
import numpy as np
import pandas as pnd
xl = pd.read_excel('Seminar8.xlsx')
xl
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930          NaN   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930          NaN   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950          NaN    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550          NaN   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550          NaN   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category          Product Name   Price  Quantity  \
# 0                               NaN                   NaN  3300.0       2.0
# ...

# %%
# hooson esehiig shalgah function data.isnull()
#data.fillna('') hooson nudend orluulah
#df=pd.DataFrame([[1, np.nan, 2]])
#data.dropna() hooson muriig ustgana 
#data.dropna(axis='columns') hooson baganiin ustgana 
#data.dropna(axis=1) columnii daguu ajilna 
#data.dropna(axis=1, how='all') buh ugugdul n nan bvl ustgana
#data.fillna() hoosn nudiig nuhuh
#data.fillna(method = 'ffill') urdald bga toogo fill hiine
#data.fillna(method = 'ffill') daraagin toogoo avch fill hiine
#xl = pnd.read_excel('temp.xlsx') file duudah

# %%
xl.dropna(axis=1, how='all')
xl.dropna()
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 7   CA-2014-115812 2014-06-09    RH-19600     Хувь хүн    Хан-Уул
# 8   CA-2014-115812 2014-06-09    RH-19600     Хувь хүн    Хан-Уул
# 9   CA-2014-115812 2014-06-09    RH-19600     Хувь хүн    Хан-Уул
# 10  CA-2014-115812 2014-06-09    RH-19600     Хувь хүн    Хан-Уул
# 14  US-2015-118983 2015-11-22    RB-19570       Гишүүн  Чингэлтэй
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category            Product Name   Price  Quantity  \
# 7                       Бичиг хэрэг     Үзгэн бал арилгадаг  2500.0       6.0
# ...
