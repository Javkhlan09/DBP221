# %%
import numpy as np
x= np.arange(0,10)
y= x*2
z= x**2
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x, color='brown')
# plt.plot(z)

# %%
plt.plot(x, linestyle='dashed',color='blue')

# %%
plt.plot(z, color='red')
